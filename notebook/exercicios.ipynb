# %% [markdown]
# # Lógica de programação com Python

# %% [markdown]
# ## Variáveis

# %%
# O resultado de uma soma de dois inteiros é um inteiro.
1+1
# Out:
# 2

# %%
# Uma string é uma sequência de caracteres.
"Guilherme"
# Out:
# 'Guilherme'

# %%
# Uma string pode ser atrubuída a uma variável.
nome = 'Guilherme'

# %%
# Ao referenciar uma variável, o Python retorna o valor dela.
nome
# Out:
# 'Guilherme'

# %%
# Um inteiro também pode ser atribuído a uma variável.
idade = 28

# %%
# A funçãpo print imprime o valor de uma variável.
print('O nome é Guilherme e sua idade é 28 anos')
# Out:
# O nome é Guilherme e sua idade é 28 anos

# %%
# Podemos inserir variáveis dentro de strings.
print(f'O nome é {nome} e sua idade é {idade} anos')
# Out:
# O nome é Guilherme e sua idade é 28 anos

# %% [markdown]
# ## Criando minha primeira função

# %%
# A função saudação solicita o nome do usuário e imprime uma saudação.
def saudacao():
    nome = input('Qual o seu nome?')
    print(f'olá {nome}')

# %%
# Ao invocar a função saudacao, o usuário é solicitadoa informar o nome.
# A função, então, imprime uma saudação.
saudacao()
# Out:
# olá Josenaldo

# %% [markdown]
# ## Passando parâmetros para a função

# %%
# Agora vamos criar uma função de saudação que usa um valor de fora da função
nome = 'Luiza'

def saudacao_com_parametros(nome_da_pessoa):
    print(f'Olá {nome_da_pessoa}')

saudacao_com_parametros(nome)
# Out:
# Olá Luiza

# %% [markdown]
# ## Condicional

# %%
# A função verifica_se_pode_dirigir verifica se a idade do usuário é maior
# que 18 e imprime se ele tem permissão para dirigir ou não.
def verica_se_pode_dirigir(idade):
    if idade >= 18:
        print('Tem permissão para dirigir')
    else:
        print('Não tem permissão para dirigir')

# %%
# João não pode dirigir porque tem menos de 18 anos.
idade_joao = 15
verica_se_pode_dirigir(idade_joao)
# Out:
# Não tem permissão para dirigir

# %%
# Maria pode dirigir porque tem 18 anos.
idade_maria = 18
verica_se_pode_dirigir(idade_maria)
# Out:
# Tem permissão para dirigir

# %%
# Ana pode dirigir porque tem mais de 18 anos.
idade_ana = 45
verica_se_pode_dirigir(idade_ana)
# Out:
# Tem permissão para dirigir

# %% [markdown]
# ## Convertendo de `str` pra `int`

# %%
# A função verifica_se_pode_dirigir_sem_parametro solicita a idade do usuário e
# verifica se o usuário é maior que 18. Ela então imprime se ele tem permissão
# para dirigir ou não.
def verifica_se_pode_dirigir_sem_parametro():
    idade = input('Qual sua idade')

    # A variável idade deve ser convertida para um inteiro.
    idade = int(idade)
    if idade >= 18:
        print(f'{idade} anos: tem permissão para dirigir')
    else:
        print(f'{idade} anos: não tem permissão para dirigir')

# %%
verifica_se_pode_dirigir_sem_parametro()
# Out:
# 12 anos: não tem permissão para dirigir

# %%
# Como verificar o tipo de uma variável
idade = 22
type(idade)
# Out:
# int

# %%
# Verificando o tipo de uma string
nome = "Guilherme"
type(nome)
# Out:
# str

# %% [markdown]
# ## Listas

# %%
# Criando uma lista de idades
idades = [18, 22, 15, 50 ]
type(idades)
# Out:
# list

# %%
# Usar o nome de uma lista retorna o valor da lista.
idades
# Out:
# [18, 22, 15, 50]

# %%
#  O valores, em uma lista, são indexados a partir do zero
idades[2]
# Out:
# 15

# %%
# Podemos selecionar uma parte da lista usando o fatiamento. Basta usar o nome
# da lista e os índices de início e fim, separados por dois-pontos. O primeiro
# índice indica o início do fatiamento e o segundo o fim, sendo que o índice
# não é incluído no fatiamento.

# Aqui, por exemplo, pegamos os elementos da lista de idades, da posição 0 até  a 1.
idades[0:2]
# Out:
# [18, 22]

# %%
# Se só o primeiro índice for informado, o Python assume que o último índice é
# o último elemento da lista.

# Assim serão coletadas todas as idades com excessão da primeira.
idades[1:]
# Out:
# [22, 15, 50]

# %%
# Se usarmos apenas o segundo índice, o Python assume que o primeiro índice é 0
idades[:2]
# Out:
# [18, 22]

# %%
# Para pegar os itens da lista, de trás para frente, basta usar o sinal de menos
idades[-1]
# Out:
# 50

# %% [markdown]
# ## Laços de repetição com `for`

# %%
idades = [18, 22, 15, 50 ]
def verifica_se_pode_dirigir(idade):
    if idade >= 18:
        print(f'{idade} anos de idade, TEM permissão para dirigir')
    else:
        print(f'{idade} anos de idade, NÃO TEM permissão para dirigir')

# com a instrução for, podemos iterar sobre uma lista.
for idade in idades:
    verifica_se_pode_dirigir(idade)
# Out:
# 18 anos de idade, TEM permissão para dirigir
# 22 anos de idade, TEM permissão para dirigir
# 15 anos de idade, NÃO TEM permissão para dirigir
# 50 anos de idade, TEM permissão para dirigir

# %%
# Podemos incluir o for dentro da função
def verifica_se_pode_dirigir_com_for(idades):
    for idade in idades:
        if idade >= 18:
            print(f'{idade} anos de idade, TEM permissão para dirigir')
        else:
            print(f'{idade} anos de idade, NÃO TEM permissão para dirigir')


idades = [18, 22, 15, 50 ]
verifica_se_pode_dirigir_com_for(idades)
# Out:
# 18 anos de idade, TEM permissão para dirigir
# 22 anos de idade, TEM permissão para dirigir
# 15 anos de idade, NÃO TEM permissão para dirigir
# 50 anos de idade, TEM permissão para dirigir

# %% [markdown]
# ## Booleano

# %%
# Uma expressão de comparação é um valor que retorna um valor booleano.
# No exemplo abaixo, a expressão retorna um valor verdadeiro
idade = 18
idade >= 18
# Out:
# True

# %%
# Uma expressão de comparação é um valor que retorna um valor booleano.
# No exemplo abaixo, a expressão retorna um valor false
idade = 15
idade >= 18
# Out:
# False

# %%
idades = [20, 14, 40]
permissoes = []

# Vamos armazenar, na lista de permissões, se o usuário tem permissão para
# dirigir ou não.
def verifica_se_pode_dirigir_e_armazena_na_lista(idades, permissoes):
    for idade in idades:
        if idade >= 18:
            permissoes.append(True)
        else:
            permissoes.append(False)

verifica_se_pode_dirigir_e_armazena_na_lista(idades, permissoes)

# %%
permissoes
# Out:
# [True, False, True]

# %%
for permissao in permissoes:
    if permissao == True:
        print('Tem permissão para dirigir')
    else:
        print('Não tem permissão para dirigir')
# Out:
# Tem permissão para dirigir
# Não tem permissão para dirigir
# Tem permissão para dirigir

# %% [markdown]
# ## Tipos em listas

# %%
# Uma lista pode armazenar 
lista = ['Guilherme', 28, True, '18']

for elemento in lista:
    print(f'O elemento {elemento} é do tipo: ', type(elemento))
# Out:
# O elemento Guilherme é do tipo:  <class 'str'>
# O elemento 28 é do tipo:  <class 'int'>
# O elemento True é do tipo:  <class 'bool'>
# O elemento 18 é do tipo:  <class 'str'>

# %% [markdown]
# ## Import

# %%
# Com o import, podemos importar
from random import randrange, seed

# %%
# Se configurarmos 
seed(11)

# %%
# Podemos gerar um valor entre 0 e 10 com a funç~]ao rad
randrange(0,11)
# Out:
# 8

# %%
# Vamos criar uma lista de notas e armazenar 8 valores aleatóprios entre 0 e 10
notas_matematica = []

for notas in range(8):
    notas_matematica.append(randrange(0,11))

notas_matematica
# Out:
# [1, 7, 4, 2, 1, 8, 10, 0]

# %%
# O tamanho da lista pode ser obtido com o comando len
len(notas_matematica)
# Out:
# 8

# %% [markdown]
# ## Matplotlib

# %%
# Importando o pyplot, do módulo matplotlib, e dando o alias plt
import matplotlib.pyplot as plt

# %%
# Para formar os pontos, temos duas listas, uma com as notas e outra com as posições no eixo x.
x = list(range(1, 9))
y = notas_matematica

# configurando os pontos no gráfico
plt.plot(x, y, marker='o')

# Título do gráfico
plt.title('Notas de matemática')

# Legenda do gráfico - eixo x e y
plt.xlabel('Provas')
plt.ylabel('Notas')

# Mostrando o gráfico
plt.show()

# %%
notas_matematica
# Out:
# [1, 7, 4, 2, 1, 8, 10, 0]
